# %%
#!pip install --upgrade torch

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils import model_zoo
from torchvision.models import vgg
from torch.utils.data import DataLoader
from torch.utils.tensorboard import SummaryWriter

import torch.optim as optim

import torchvision
import torchvision.transforms as transforms
from torchvision import datasets

from PIL import Image

import numpy as np

import matplotlib.pyplot as plt

# %%
# Подключение к Google Drive при помощи Oauth Access Token
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# Класс по обработке Изображений
class ImageHandler:

    def __init__(self, image_size, content_image_path, style_image_path, device):
        self.image_size = image_size
        self.device = device
        self.content_image = self.image_loader(content_image_path)
        self.style_image = self.image_loader(style_image_path)
        #assert self.content_image.size() == self.style_image.size(), "The content and style image must be of the same size"

    def image_loader(self, image_path):
        loader = transforms.Compose([
            transforms.Resize(self.image_size),
            transforms.ToTensor()
        ])
        image = Image.open(image_path)
        image = loader(image).unsqueeze(0)
        return image.to(self.device, torch.float)

    def image_unloader(self, tensor):
        unloader = transforms.Compose([
            transforms.ToPILImage()
        ])
        image = tensor.cpu().clone()
        image = image.squeeze(0)
        return unloader(image)

    def imshow(self, tensor, title=None):
        image = self.image_unloader(tensor)
        plt.imshow(image)
        if title is not None:
            plt.title(title)
        plt.show()

# %%
class TrainStyleImageHandler:

    def __init__(self, image_size, style_image_path, dataset_path, batch_size, device,):
        self.image_size = image_size
        self.device = device

        train_dataset = datasets.ImageFolder(dataset_path, self.loader)
        self.train_loader = DataLoader(train_dataset, batch_size=batch_size)

        self.style_image = self.style_image_loader(style_image_path, batch_size)

    @property
    def loader(self):
        return transforms.Compose([
            transforms.Resize(self.image_size),
            transforms.CenterCrop(self.image_size),
            transforms.ToTensor(),
        ])

    def style_image_loader(self, style_image_path, batch_size):
        style_image = Image.open(style_image_path)
        style_image = self.loader(style_image)
        style_image = style_image.repeat(batch_size, 1, 1, 1)
        return style_image.to(self.device, torch.float)

# %%
def get_last_used_conv_layer(layer_names):
    layers = []
    for name in layer_names:
        a, b = name.split('_')[1:]
        layers.append((int(a), int(b)))
    return 'conv_%s_%s' % sorted(layers)[-1]

# %%
class ConvPadded(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size, stride):
        super(ConvPadded, self).__init__()
        reflection_padding = kernel_size // 2
        self.reflection_pad = nn.ReflectionPad2d(reflection_padding)
        self.conv2d = nn.Conv2d(in_channels, out_channels, kernel_size, stride)

    def forward(self, x):
        out = self.reflection_pad(x)
        out = self.conv2d(out)
        return out

# %%
class Residual(nn.Module):

    def __init__(self, channels):
        super(Residual, self).__init__()
        self.conv_1 = ConvPadded(channels, channels, kernel_size=3, stride=1)
        self.instance_norm_1 = nn.InstanceNorm2d(channels, affine=True)
        self.conv_2 = ConvPadded(channels, channels, kernel_size=3, stride=1)
        self.instance_norm_2 = nn.InstanceNorm2d(channels, affine=True)
        self.relu = nn.ReLU()

    def forward(self, x):
        out = self.relu(self.instance_norm_1(self.conv_1(x)))
        out = self.instance_norm_2(self.conv_2(out))
        return out + x

# %%
class UpsampleConv(nn.Module):

    def __init__(self, in_channels, out_channels, kernel_size, stride, upsample):
        super(UpsampleConv, self).__init__()
        self.upsample_layer = nn.Upsample(mode='nearest', scale_factor=upsample)
        reflection_padding = kernel_size // 2
        self.reflection_pad = nn.ReflectionPad2d(reflection_padding)
        self.conv2d = nn.Conv2d(in_channels, out_channels, kernel_size, stride)

    def forward(self, x):
        out = self.upsample_layer(x)
        out = self.reflection_pad(out)
        return self.conv2d(out)

# %%
class Normalization(nn.Module):
    def __init__(self, mean, std):
        super(Normalization, self).__init__()
        self.mean = torch.tensor(mean).view(-1, 1, 1)
        self.std = torch.tensor(std).view(-1, 1, 1)

    def forward(self, img):
        return (img - self.mean) / self.std

# %%
class TransformNetwork(nn.Module):

    def __init__(self):
        super(TransformNetwork, self).__init__()
        # initial layers
        self.conv_1 = ConvPadded(3, 32, kernel_size=9, stride=1)
        self.instance_norm_1 = nn.InstanceNorm2d(32, affine=True)
        self.conv_2 = ConvPadded(32, 64, kernel_size=3, stride=2)
        self.instance_norm_2 = nn.InstanceNorm2d(64, affine=True)
        self.conv_3 = ConvPadded(64, 128, kernel_size=3, stride=2)
        self.instance_norm_3 = nn.InstanceNorm2d(128, affine=True)
        # residual layers
        self.residual_1 = Residual(128)
        self.residual_2 = Residual(128)
        self.residual_3 = Residual(128)
        self.residual_4 = Residual(128)
        self.residual_5 = Residual(128)
        # upsampling layers
        self.deconv_1 = UpsampleConv(128, 64, kernel_size=3, stride=1, upsample=2)
        self.instance_norm_4 = torch.nn.InstanceNorm2d(64, affine=True)
        self.deconv_2 = UpsampleConv(64, 32, kernel_size=3, stride=1, upsample=2)
        self.instance_norm_5 = torch.nn.InstanceNorm2d(32, affine=True)
        self.deconv_3 = ConvPadded(32, 3, kernel_size=9, stride=1)

        # non linear layer
        self.relu = nn.ReLU()

    def forward(self, x):
        out = self.relu(self.instance_norm_1(self.conv_1(x)))
        out = self.relu(self.instance_norm_2(self.conv_2(out)))
        out = self.relu(self.instance_norm_3(self.conv_3(out)))

        out = self.residual_1(out)
        out = self.residual_2(out)
        out = self.residual_3(out)
        out = self.residual_4(out)
        out = self.residual_5(out)

        out = self.relu(self.instance_norm_4(self.deconv_1(out)))
        out = self.relu(self.instance_norm_5(self.deconv_2(out)))
        out = self.deconv_3(out)

        return out

# %%
class TransferVgg(nn.Module):

    def __init__(self, layers):
        super(TransferVgg, self).__init__()
        self.layer_names = []
        for layer_name, layer in layers:
            setattr(self, layer_name, layer)
            self.layer_names.append(layer_name)

    def forward(self, x, out_keys):
        out = {}
        for layer_name in self.layer_names:
            layer = getattr(self, layer_name)
            if isinstance(layer, nn.Conv2d):
                out[layer_name] = F.relu(layer(x))
            else:
                out[layer_name] = layer(x)
            x = out[layer_name]
        return {key: value for key, value in out.items() if key in out_keys}

    @classmethod
    def factory(cls, cfg, last_layer, mean, std):
        layers = [('normalization', Normalization(mean, std))]
        in_channels = 3
        conv_layer = 1
        conv_layer_number = 1
        pool_layer_number = 1
        for v in cfg:
            if v == 'M':
                layers.append(('pool_%s' % pool_layer_number, nn.MaxPool2d(kernel_size=2, stride=2)))
                pool_layer_number += 1
                conv_layer += 1
                conv_layer_number = 1
            else:
                conv_layer_name = 'conv_%s_%s' % (conv_layer, conv_layer_number)
                layers.append((conv_layer_name, nn.Conv2d(in_channels,
                                                          v,
                                                          kernel_size=3,
                                                          padding=1)))
                in_channels = v
                if conv_layer_name == last_layer:
                    break
                conv_layer_number += 1
        return cls(layers)

# %%
def transfer_vgg19(last_layer, device):
        mean = torch.tensor([0.485, 0.456, 0.406]).to(device)
        std = torch.tensor([0.229, 0.224, 0.225]).to(device)
       
        model = TransferVgg.factory(cfg=vgg.cfgs['E'], last_layer=last_layer, mean=mean, std=std)
        
        state_dict = model_zoo.load_url(vgg.model_urls['vgg19'], model_dir="/content/gdrive/My Drive", progress=True)

        mapping = {
            'conv_1_1': 'features.0',
            'conv_1_2': 'features.2',
            'conv_2_1': 'features.5',
            'conv_2_2': 'features.7',
            'conv_3_1': 'features.10',
            'conv_3_2': 'features.12',
            'conv_3_3': 'features.14',
            'conv_3_4': 'features.16',
            'conv_4_1': 'features.19',
            'conv_4_2': 'features.21',
            'conv_4_3': 'features.23',
            'conv_4_4': 'features.25',
            'conv_5_1': 'features.28',
            'conv_5_2': 'features.30',
            'conv_5_3': 'features.32',
            'conv_5_4': 'features.34',
        }

        new_state_dict = {}
        for key, map_to in mapping.items():
            new_state_dict['%s.weight' % key] = state_dict['%s.weight' % map_to]
            new_state_dict['%s.bias' % key] = state_dict['%s.bias' % map_to]
            if key == last_layer:
                break
        model.load_state_dict(new_state_dict)
        for param in model.parameters():
            param.requires_grad = False
        return model.to(device).eval()

# %%
class StyleLoss(nn.Module):

    def __init__(self, weight):
        super(StyleLoss, self).__init__()
        self.weight = weight

    def forward(self, input, target):
        G_input = self.gram_matrix(input)
        G_target = self.gram_matrix(target).detach()
        return self.weight * F.mse_loss(G_input, G_target)

    def gram_matrix(self, input):
        a, b, c, d = input.size()
        features = input.view(a * b, c * d)
        G = torch.mm(features, features.t())
        return G.div(a * b * c * d)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %%
image_handler = ImageHandler(image_size=800,
                                 content_image_path="/content/gdrive/My Drive/noise.jpg",
                                 style_image_path="/content/gdrive/My Drive/fractal.jpg",
                                 device=device)
style_layer_names = ['conv_1_1', 'conv_2_1', 'conv_3_1', 'conv_4_1', 'conv_5_1']
layer_names = style_layer_names

last_layer = get_last_used_conv_layer(layer_names)
model = transfer_vgg19(last_layer, device)

print('Model:' , model)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# Model: TransferVgg(
#   (normalization): Normalization()
#   (conv_1_1): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv_1_2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool_1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv_2_1): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv_2_2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool_2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv_3_1): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv_3_2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv_3_3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv_3_4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool_3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv_4_1): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv_4_2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv_4_3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv_4_4): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool_4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv_5_1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# )

# %%
style_layers = ['conv_1_1', 'conv_2_1', 'conv_3_1', 'conv_4_1', 'conv_5_1']

style_weights = [float(w) for w in '64000,128000,256000,512000,512000'.split(',')]
if len(style_weights) == 1:
  style_weights = [style_weights[0]] * len(style_layers)
else:
  assert len(style_weights) == len(style_layers)
style_layers_weights = {n: w for n, w in zip(style_layers, style_weights)}

# %%
style_features = model(image_handler.style_image, style_layer_names)

style_losses = {layer_name: StyleLoss(weight=weight)
                    for layer_name, weight in style_layers_weights.items()}

combination_image = image_handler.content_image.clone()
optimizer = optim.LBFGS([combination_image.requires_grad_()])

# %%
run = [0]
while run[0] <= 700:
    def closure():
        # correct the values of updated input image
        combination_image.data.clamp_(0, 1)

        optimizer.zero_grad()
        out = model(combination_image, layer_names)

        style_score = torch.sum(torch.stack([loss(out[layer_name], style_features[layer_name].detach())
                                                for layer_name, loss in style_losses.items()]))

        loss = style_score
        loss.backward()

        run[0] += 1
        print("run {}:".format(run))
        print('Style Loss : {:4f}'.format(style_score.item()))

        if run[0] % 50 == 0:
          torchvision.utils.save_image(combination_image, "/content/gdrive/My Drive/fractal_style_loss_noise_{}.png".format(str(run)[1:-1]))
          print('Image Saved:' ,"{}.jpg".format(run))
        
        return loss

    optimizer.step(closure)

combination_image.data.clamp_(0, 1)

image_handler.image_unloader(combination_image)
# Out:
# run [1]:
# Style Loss : 189.516113
# run [2]:
# Style Loss : 189.510498
# run [3]:
# Style Loss : 156.230087
# run [4]:
# Style Loss : 138.881729
# run [5]:
# Style Loss : 125.524422
# run [6]:
# Style Loss : 109.945221
# run [7]:
# Style Loss : 93.766617
# run [8]:
# Style Loss : 82.775230
# run [9]:
# Style Loss : 73.579483
# run [10]:
# Style Loss : 68.579247
# run [11]:
# Style Loss : 61.427631
# run [12]:
# Style Loss : 55.859062
# run [13]:
# Style Loss : 52.945473
# run [14]:
# Style Loss : 48.533070
# run [15]:
# Style Loss : 45.808865
# run [16]:
# Style Loss : 43.417809
# run [17]:
# Style Loss : 40.583633
# run [18]:
# Style Loss : 39.095535
# run [19]:
# Style Loss : 36.593975
# run [20]:
# Style Loss : 35.132500
# run [21]:
# Style Loss : 34.227345
# run [22]:
# Style Loss : 33.360588
# run [23]:
# Style Loss : 31.822639
# run [24]:
# Style Loss : 30.190636
# run [25]:
# Style Loss : 29.175503
# run [26]:
# Style Loss : 27.826593
# run [27]:
# Style Loss : 27.104231
# run [28]:
# Style Loss : 26.268059
# run [29]:
# Style Loss : 25.759136
# run [30]:
# Style Loss : 24.792400
# run [31]:
# Style Loss : 23.607698
# run [32]:
# Style Loss : 22.612577
# run [33]:
# Style Loss : 21.832689
# run [34]:
# Style Loss : 20.984842
# run [35]:
# Style Loss : 20.550419
# run [36]:
# Style Loss : 19.878160
# run [37]:
# Style Loss : 19.448742
# run [38]:
# Style Loss : 18.906624
# run [39]:
# Style Loss : 18.404995
# run [40]:
# Style Loss : 17.980873
# run [41]:
# Style Loss : 17.479015
# run [42]:
# Style Loss : 17.059893
# run [43]:
# Style Loss : 16.615593
# run [44]:
# Style Loss : 16.297104
# run [45]:
# Style Loss : 15.965953
# run [46]:
# Style Loss : 15.673840
# run [47]:
# Style Loss : 15.299215
# run [48]:
# Style Loss : 14.927597
# run [49]:
# Style Loss : 14.571711
# run [50]:
# Style Loss : 14.390715
# Image Saved: [50].jpg
# run [51]:
# Style Loss : 14.187686
# run [52]:
# Style Loss : 13.904880
# run [53]:
# Style Loss : 13.643517
# run [54]:
# Style Loss : 13.371960
# run [55]:
# Style Loss : 13.082616
# run [56]:
# Style Loss : 12.811367
# run [57]:
# Style Loss : 12.586237
# run [58]:
# Style Loss : 12.441671
# run [59]:
# Style Loss : 12.263896
# run [60]:
# Style Loss : 12.084518
# run [61]:
# Style Loss : 11.909786
# run [62]:
# Style Loss : 11.717146
# run [63]:
# Style Loss : 11.539233
# run [64]:
# Style Loss : 11.412384
# run [65]:
# Style Loss : 11.289537
# run [66]:
# Style Loss : 11.141655
# run [67]:
# Style Loss : 10.982901
# run [68]:
# Style Loss : 10.828682
# run [69]:
# Style Loss : 10.727906
# run [70]:
# Style Loss : 10.536911
# run [71]:
# Style Loss : 10.390443
# run [72]:
# Style Loss : 10.276644
# run [73]:
# Style Loss : 10.174080
# run [74]:
# Style Loss : 10.041884
# run [75]:
# Style Loss : 9.915215
# run [76]:
# Style Loss : 9.785441
# run [77]:
# Style Loss : 9.685745
# run [78]:
# Style Loss : 9.591433
# run [79]:
# Style Loss : 9.511053
# run [80]:
# Style Loss : 9.408455
# run [81]:
# Style Loss : 9.302859
# run [82]:
# Style Loss : 9.193524
# run [83]:
# Style Loss : 9.102364
# run [84]:
# Style Loss : 9.012660
# run [85]:
# Style Loss : 8.935526
# run [86]:
# Style Loss : 8.843842
# run [87]:
# Style Loss : 8.786862
# run [88]:
# Style Loss : 8.707461
# run [89]:
# Style Loss : 8.648802
# run [90]:
# Style Loss : 8.577430
# run [91]:
# Style Loss : 8.499992
# run [92]:
# Style Loss : 8.414503
# run [93]:
# Style Loss : 4.344275
# run [330]:
# Style Loss : 5.494367
# run [331]:
# Style Loss : 5.230801
# run [332]:
# Style Loss : 17.998768
# run [333]:
# Style Loss : 4.832257
# run [334]:
# Style Loss : 4.838748
# run [335]:
# Style Loss : 4.720000
# run [336]:
# Style Loss : 4.658942
# run [337]:
# Style Loss : 4.566926
# run [338]:
# Style Loss : 4.505090
# run [339]:
# Style Loss : 4.468279
# run [340]:
# Style Loss : 4.418031
# run [341]:
# Style Loss : 4.374433
# run [342]:
# Style Loss : 4.331933
# run [343]:
# Style Loss : 4.301276
# run [344]:
# Style Loss : 4.276029
# run [345]:
# Style Loss : 4.257595
# run [346]:
# Style Loss : 4.249526
# run [347]:
# Style Loss : 4.256832
# run [348]:
# Style Loss : 4.236411
# run [349]:
# Style Loss : 4.215443
# run [350]:
# Style Loss : 4.199270
# Image Saved: [350].jpg
# run [351]:
# Style Loss : 4.425303
# run [352]:
# Style Loss : 4.371234
# run [353]:
# Style Loss : 4.605418
# run [354]:
# Style Loss : 4.638851
# run [355]:
# Style Loss : 4.808293
# run [356]:
# Style Loss : 4.680614
# run [357]:
# Style Loss : 4.444788
# run [358]:
# Style Loss : 4.341037
# run [359]:
# Style Loss : 4.285126
# run [360]:
# Style Loss : 4.259295
# run [361]:
# Style Loss : 4.228030
# run [362]:
# Style Loss : 4.189023
# run [363]:
# Style Loss : 4.165771
# run [364]:
# Style Loss : 4.181609
# run [365]:
# Style Loss : 4.218361
# run [366]:
# Style Loss : 4.184466
# run [367]:
# Style Loss : 4.142739
# run [368]:
# Style Loss : 4.223989
# run [369]:
# Style Loss : 4.567369
# run [370]:
# Style Loss : 12.229214
# run [371]:
# Style Loss : 73.690834
# run [372]:
# Style Loss : 68.608337
# run [373]:
# Style Loss : 74.446510
# run [374]:
# Style Loss : 193.716446
# run [375]:
# Style Loss : 163.513550
# run [376]:
# Style Loss : 185.460953
# run [377]:
# Style Loss : 112.847931
# run [378]:
# Style Loss : 94.675613
# run [379]:
# Style Loss : 127.400597
# run [380]:
# Style Loss : 72.998566
# run [381]:
# Style Loss : 64.628166
# run [382]:
# Style Loss : 43.943726
# run [383]:
# Style Loss : 44.647087
# run [384]:
# Style Loss : 32.368328
# run [385]:
# Style Loss : 28.991005
# run [386]:
# Style Loss : 26.546503
# run [387]:
# Style Loss : 23.114506
# run [388]:
# Style Loss : 20.347979
# run [389]:
# Style Loss : 18.382477
# run [390]:
# Style Loss : 17.075993
# run [391]:
# Style Loss : 16.399040
# run [392]:
# Style Loss : 15.655625
# run [393]:
# Style Loss : 14.456191
# run [394]:
# Style Loss : 13.400529
# run [395]:
# Style Loss : 12.422174
# run [396]:
# Style Loss : 11.683127
# run [397]:
# Style Loss : 11.233899
# run [398]:
# Style Loss : 10.997723
# run [399]:
# Style Loss : 10.684990
# run [400]:
# Style Loss : 10.262428
# Image Saved: [400].jpg
# run [401]:
# Style Loss : 9.774385
# run [402]:
# Style Loss : 9.374162
# run [403]:
# Style Loss : 9.083934
# run [404]:
# Style Loss : 8.799755
# run [405]:
# Style Loss : 8.622688
# run [406]:
# Style Loss : 8.385218
# run [407]:
# Style Loss : 8.130660
# run [487]:
# Style Loss : 4.102057
# run [488]:
# Style Loss : 4.087492
# run [489]:
# Style Loss : 4.080027
# run [490]:
# Style Loss : 4.061788
# run [491]:
# Style Loss : 4.053178
# run [492]:
# Style Loss : 4.037208
# run [493]:
# Style Loss : 4.025691
# run [494]:
# Style Loss : 4.017206
# run [495]:
# Style Loss : 4.008364
# run [496]:
# Style Loss : 3.996910
# run [497]:
# Style Loss : 3.985884
# run [498]:
# Style Loss : 3.972709
# run [499]:
# Style Loss : 3.963174
# run [500]:
# Style Loss : 3.949612
# Image Saved: [500].jpg
# run [501]:
# Style Loss : 3.941880
# run [502]:
# Style Loss : 3.930251
# run [503]:
# Style Loss : 3.924816
# run [504]:
# Style Loss : 3.912672
# run [505]:
# Style Loss : 3.907653
# run [506]:
# Style Loss : 3.897756
# run [507]:
# Style Loss : 3.890822
# run [508]:
# Style Loss : 3.879813
# run [509]:
# Style Loss : 3.875789
# run [510]:
# Style Loss : 3.862453
# run [511]:
# Style Loss : 3.856504
# run [512]:
# Style Loss : 3.846809
# run [513]:
# Style Loss : 3.839054
# run [514]:
# Style Loss : 3.835082
# run [515]:
# Style Loss : 3.825880
# run [516]:
# Style Loss : 3.825002
# run [517]:
# Style Loss : 3.815280
# run [518]:
# Style Loss : 3.803974
# run [519]:
# Style Loss : 3.802147
# run [520]:
# Style Loss : 3.795281
# run [521]:
# Style Loss : 3.786344
# run [522]:
# Style Loss : 3.786664
# run [523]:
# Style Loss : 3.781432
# run [524]:
# Style Loss : 3.768993
# run [525]:
# Style Loss : 3.826240
# run [526]:
# Style Loss : 3.801983
# run [527]:
# Style Loss : 3.850958
# run [528]:
# Style Loss : 3.816596
# run [529]:
# Style Loss : 3.800467
# run [530]:
# Style Loss : 3.774017
# run [531]:
# Style Loss : 3.748067
# run [532]:
# Style Loss : 3.731469
# run [533]:
# Style Loss : 3.718927
# run [534]:
# Style Loss : 3.709410
# run [535]:
# Style Loss : 3.704502
# run [536]:
# Style Loss : 3.703296
# run [537]:
# Style Loss : 3.708701
# run [538]:
# Style Loss : 3.719838
# run [539]:
# Style Loss : 3.717145
# run [540]:
# Style Loss : 3.711314
# run [541]:
# Style Loss : 3.692943
# run [542]:
# Style Loss : 3.736309
# run [543]:
# Style Loss : 3.707580
# run [544]:
# Style Loss : 3.693901
# run [545]:
# Style Loss : 3.693210
# run [546]:
# Style Loss : 3.676086
# run [547]:
# Style Loss : 3.667689
# run [548]:
# Style Loss : 3.664616
# run [549]:
# Style Loss : 3.655217
# run [550]:
# Style Loss : 3.652668
# Image Saved: [550].jpg
# run [551]:
# Style Loss : 3.655575
# run [552]:
# Style Loss : 3.673013
# run [553]:
# Style Loss : 3.675380
# run [554]:
# Style Loss : 3.657146
# run [555]:
# Style Loss : 3.652766
# run [556]:
# Style Loss : 3.642495
# run [557]:
# Style Loss : 3.631988
# run [558]:
# Style Loss : 3.642789
# run [559]:
# Style Loss : 3.670077
# run [560]:
# Style Loss : 3.644296
# run [561]:
# Style Loss : 3.626952
# run [562]:
# Style Loss : 3.628805
# run [563]:
# Style Loss : 3.629026
# run [564]:
# Style Loss : 3.614226
# run [565]:
# Style Loss : 3.609034
# run [566]:
# Style Loss : 3.659853
# run [567]:
# Style Loss : 3.681414
# run [568]:
# Style Loss : 3.692628
# run [569]:
# Style Loss : 3.914377
# run [570]:
# Style Loss : 3.770277
# run [571]:
# Style Loss : 3.723989
# run [572]:
# Style Loss : 3.680338
# run [573]:
# Style Loss : 3.649276
# run [574]:
# Style Loss : 3.625955
# run [575]:
# Style Loss : 3.607456
# run [576]:
# Style Loss : 3.585568
# run [577]:
# Style Loss : 3.572903
# run [578]:
# Style Loss : 3.559983
# run [579]:
# Style Loss : 3.550241
# run [580]:
# Style Loss : 3.553560
# run [581]:
# Style Loss : 3.550095
# run [582]:
# Style Loss : 3.562826
# run [583]:
# Style Loss : 3.581845
# run [584]:
# Style Loss : 3.573338
# run [585]:
# Style Loss : 3.592017
# run [586]:
# Style Loss : 3.591455
# run [587]:
# Style Loss : 3.709749
# run [588]:
# Style Loss : 3.726322
# run [589]:
# Style Loss : 3.884465
# run [590]:
# Style Loss : 3.698252
# run [591]:
# Style Loss : 3.715475
# run [592]:
# Style Loss : 3.643235
# run [593]:
# Style Loss : 3.629850
# run [594]:
# Style Loss : 3.619143
# run [595]:
# Style Loss : 3.587127
# run [596]:
# Style Loss : 3.574507
# run [597]:
# Style Loss : 3.552980
# run [598]:
# Style Loss : 3.542835
# run [599]:
# Style Loss : 3.545879
# run [600]:
# Style Loss : 3.528963
# Image Saved: [600].jpg
# run [601]:
# Style Loss : 3.528598
# run [602]:
# Style Loss : 3.652894
# run [603]:
# Style Loss : 3.715125
# run [604]:
# Style Loss : 3.794535
# run [605]:
# Style Loss : 3.850867
# run [606]:
# Style Loss : 3.870057
# run [607]:
# Style Loss : 3.922134
# run [608]:
# Style Loss : 3.800839
# run [609]:
# Style Loss : 3.739565
# run [610]:
# Style Loss : 3.679236
# run [611]:
# Style Loss : 3.649825
# run [612]:
# Style Loss : 3.631717
# run [613]:
# Style Loss : 3.609211
# run [614]:
# Style Loss : 3.582509
# run [615]:
# Style Loss : 3.561021
# run [616]:
# Style Loss : 3.553833
# run [617]:
# Style Loss : 3.560148
# run [618]:
# Style Loss : 3.545330
# run [619]:
# Style Loss : 3.539001
# run [620]:
# Style Loss : 3.554565
# run [621]:
# Style Loss : 3.696220
# run [622]:
# Style Loss : 3.624129
# run [623]:
# Style Loss : 3.682248
# run [624]:
# Style Loss : 3.711249
# run [625]:
# Style Loss : 3.601904
# run [626]:
# Style Loss : 3.585747
# run [627]:
# Style Loss : 3.573033
# run [628]:
# Style Loss : 3.590308
# run [629]:
# Style Loss : 3.870775
# run [630]:
# Style Loss : 4.490278
# run [631]:
# Style Loss : 5.021238
# run [632]:
# Style Loss : 4.582566
# run [633]:
# Style Loss : 9.645483
# run [634]:
# Style Loss : 9.752234
# run [635]:
# Style Loss : 14.012133
# run [636]:
# Style Loss : 8.631228
# run [637]:
# Style Loss : 9.384611
# run [638]:
# Style Loss : 11.278814
# run [639]:
# Style Loss : 7.207360
# run [640]:
# Style Loss : 6.809943
# run [641]:
# Style Loss : 6.345089
# run [642]:
# Style Loss : 6.496703
# run [643]:
# Style Loss : 5.635094
# run [644]:
# Style Loss : 5.462066
# run [645]:
# Style Loss : 5.226837
# run [646]:
# Style Loss : 5.014857
# run [647]:
# Style Loss : 4.808968
# run [648]:
# Style Loss : 4.746920
# run [649]:
# Style Loss : 4.672903
# run [650]:
# Style Loss : 4.551924
# Image Saved: [650].jpg
# run [651]:
# Style Loss : 4.481705
# run [652]:
# Style Loss : 4.356453
# run [653]:
# Style Loss : 4.266926
# run [654]:
# Style Loss : 4.206141
# run [655]:
# Style Loss : 4.140561
# run [656]:
# Style Loss : 4.066682
# run [657]:
# Style Loss : 4.014543
# run [658]:
# Style Loss : 3.970564
# run [659]:
# Style Loss : 3.942793
# run [660]:
# Style Loss : 3.916353
# run [661]:
# Style Loss : 3.886660
# run [662]:
# Style Loss : 3.854185
# run [663]:
# Style Loss : 3.813504
# run [664]:
# Style Loss : 3.777131
# run [665]:
# Style Loss : 3.756020
# run [666]:
# Style Loss : 3.740098
# run [667]:
# Style Loss : 3.719540
# run [668]:
# Style Loss : 3.691962
# run [669]:
# Style Loss : 3.670089
# run [670]:
# Style Loss : 3.638743
# run [671]:
# Style Loss : 3.620549
# run [672]:
# Style Loss : 3.604265
# run [673]:
# Style Loss : 3.585237
# run [674]:
# Style Loss : 3.567524
# run [675]:
# Style Loss : 3.558067
# run [676]:
# Style Loss : 3.541551
# run [677]:
# Style Loss : 3.532135
# run [678]:
# Style Loss : 3.523061
# run [679]:
# Style Loss : 3.514585
# run [680]:
# Style Loss : 3.497002
# run [681]:
# Style Loss : 3.492187
# run [682]:
# Style Loss : 3.514249
# run [683]:
# Style Loss : 3.498523
# run [684]:
# Style Loss : 3.478816
# run [685]:
# Style Loss : 3.478138
# run [686]:
# Style Loss : 3.503789
# run [687]:
# Style Loss : 3.488666
# run [688]:
# Style Loss : 3.511608
# run [689]:
# Style Loss : 3.714702
# run [690]:
# Style Loss : 3.683901
# run [691]:
# Style Loss : 4.007991
# run [692]:
# Style Loss : 3.926564
# run [693]:
# Style Loss : 3.691079
# run [694]:
# Style Loss : 3.651108
# run [695]:
# Style Loss : 3.629715
# run [696]:
# Style Loss : 3.575721
# run [697]:
# Style Loss : 3.544708
# run [698]:
# Style Loss : 3.546342
# run [699]:
# Style Loss : 3.541888
# run [700]:
# Style Loss : 3.516331
# Image Saved: [700].jpg
# run [701]:
# Style Loss : 3.507343
# run [702]:
# Style Loss : 4.582129
# run [703]:
# Style Loss : 5.346630
# run [704]:
# Style Loss : 57.804356
# run [705]:
# Style Loss : 732.552612
# run [706]:
# Style Loss : 502.510193
# run [707]:
# Style Loss : 10376.888672
# run [708]:
# Style Loss : 6943.465332
# run [709]:
# Style Loss : 6107.816895
# run [710]:
# Style Loss : 14009.833984
# run [711]:
# Style Loss : 9932.125977
# run [712]:
# Style Loss : 4250.486816
# run [713]:
# Style Loss : 4882.642578
# run [714]:
# Style Loss : 1774.523926
# run [715]:
# Style Loss : 1189.305664
# run [716]:
# Style Loss : 439.605988
# run [717]:
# Style Loss : 278.288574
# run [718]:
# Style Loss : 202.202423
# run [719]:
# Style Loss : 170.806519
# run [720]:
# Style Loss : 143.057297
# <PIL.Image.Image image mode=L size=1066x800 at 0x7F3718FD3668>
